# %% [markdown]
# # Requesting openai using HTTP request and response
#  Directly place a request to openai server without sdk installed

# %%
# Install package manager
# !pip install uv 
# !pip install requests

# %%
import os
from dotenv import load_dotenv
import requests
import json

load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")
openai_url = "https://api.openai.com/v1/chat/completions"

headers={
    "Authorization":f"Bearer {api_key}",
    "Conent-type": "application/json"
}

payload={
    "model":"gpt-4o-mini",
    "messages":[
        {"role":"system","content":"You are a movie reviewer"},
        {"role":"user","content":"Name the famous comedy hollywood movie, give me top one name"}
    ]
}

response = requests.post(openai_url, headers=headers, json=payload)
print(response.json())
# Out:
# {'id': 'chatcmpl-E9SBHAmnMruyqALTt5eLZGZD8THvN', 'object': 'chat.completion', 'created': 1785921987, 'model': 'gpt-4o-mini-2024-07-18', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': 'One of the most famous comedy Hollywood movies is "Superbad." Released in 2007, it has become a classic in the genre, known for its humor and relatable coming-of-age themes.', 'refusal': None, 'annotations': []}, 'logprobs': None, 'finish_reason': 'stop'}], 'usage': {'prompt_tokens': 28, 'completion_tokens': 39, 'total_tokens': 67, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'service_tier': 'default', 'system_fingerprint': 'fp_18fc98c6d2'}
